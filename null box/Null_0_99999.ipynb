# %%
import pandas as pd
import numpy as np
# List of Tuples
empoyees = [('Jack', np.NaN, 34, 'Sydney', np.NaN,  5,  np.NaN, np.NaN, np.NaN),
            ('Riti', 23    , 31, np.NaN , np.NaN,  7,  np.NaN, np.NaN, np.NaN),
            (np.NaN, np.NaN, 16, 'London', 32,      11, np.NaN, 3, np.NaN),
            ('Mark', np.NaN, 41, 'Delhi' , np.NaN,  12, np.NaN, 11, 1)]


# Create a DataFrame object
df = pd.DataFrame(  empoyees,
                    columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'])



df
# Out:
#       A     B   C       D     E   F   G     H    I
# 0  Jack   NaN  34  Sydney   NaN   5 NaN   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7 NaN   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11 NaN   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12 NaN  11.0  1.0

# %% [markdown]
# cols = df.columns[df.isnull().mean()>0.95]
# df.drop(cols, axis=1,inplace=True)

# %%
def null_value_treatment(df,value):
    for col in df.columns: 
        if (df[col].isnull().sum())/(len(df)) > 0.95: 
            del df[col]
        return df.transform(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0))

# %%
null_value_treatment(df,0.95)
# Out:
#         A     B   C       D     E   F    G     H    I
# 0    Jack   0.0  34  Sydney   0.0   5  0.0   0.0  0.0
# 1    Riti  23.0  31  -99999   0.0   7  0.0   0.0  0.0
# 2  -99999   0.0  16  London  32.0  11  0.0   3.0  0.0
# 3    Mark   0.0  41   Delhi   0.0  12  0.0  11.0  1.0

# %% [markdown]
# def missingvaluecol(df,threshold):
#     perc = 95.0
#     min_count =  int(((100-perc)/100)*df.shape[0])
#     df = df.dropna( axis=1, thresh=min_count,inplace=True)

# %%
df.isnull().sum()/len(df)*100
# Out:
# A     25.0
# B     75.0
# C      0.0
# D     25.0
# E     75.0
# F      0.0
# G    100.0
# H     50.0
# I     75.0
# dtype: float64

# %%
df
# Out:
#       A     B   C       D     E   F   G     H    I
# 0  Jack   NaN  34  Sydney   NaN   5 NaN   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7 NaN   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11 NaN   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12 NaN  11.0  1.0

# %%
len(df)
# Out:
# 4

# %%
df.isnull().sum() / len(df)
# Out:
# A     25.0
# B     75.0
# C      0.0
# D     25.0
# E     75.0
# F      0.0
# G    100.0
# H     50.0
# I     75.0
# dtype: float64

# %%
df.isnull().sum()
# Out:
# A    1
# B    3
# C    0
# D    1
# E    3
# F    0
# G    4
# H    2
# I    3
# dtype: int64

# %%
A=df.isnull().sum() / len(df)

# %%
A[A > 0.80].index
# Out:
# Index(['G'], dtype='object')

# %%
A[A > 0.80][0]
# Out:
# 1.0

# %%
def missingvaluecol(dff, value):
    
    p_null = df.isnull().sum() / len(df)
    
    missing_features = p_null[p_null > 0.95].index
    
    df.drop(missing_features, axis=1, inplace=True)

# %%
missingvaluecol(df,95)

# %%
df
# Out:
#       A     B   C       D     E   F     H    I
# 0  Jack   NaN  34  Sydney   NaN   5   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12  11.0  1.0

# %%
df
# Out:
#       A     B   C       D     E   F     H    I
# 0  Jack   NaN  34  Sydney   NaN   5   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12  11.0  1.0

# %%
df.astype('str').replace({'-99999': np.nan, 'nan': np.nan}, regex=True).astype('object')
#This makes sure already existing np.nan are not lost
# Out:
#       A     B   C       D     E   F     H    I
# 0  Jack   NaN  34  Sydney   NaN   5   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12  11.0  1.0

# %%
df
# Out:
#       A     B   C       D     E   F   G     H    I
# 0  Jack   NaN  34  Sydney   NaN   5 NaN   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7 NaN   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11 NaN   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12 NaN  11.0  1.0

# %%
import pandas as pd
import numpy as np
# List of Tuples
empoyees = [('Jack', np.NaN, 34, 'Sydney', np.NaN,  5,  np.NaN, np.NaN, np.NaN),
            ('Riti', 23    , 31, np.NaN , np.NaN,  7,  np.NaN, np.NaN, np.NaN),
            (np.NaN, np.NaN, 16, 'London', 32,      11, np.NaN, 3, np.NaN),
            ('Mark', np.NaN, 41, 'Delhi' , np.NaN,  12, np.NaN, 11, 1)]


# Create a DataFrame object
df = pd.DataFrame(  empoyees,
                    columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'])



df
# Out:
#       A     B   C       D     E   F   G     H    I
# 0  Jack   NaN  34  Sydney   NaN   5 NaN   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7 NaN   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11 NaN   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12 NaN  11.0  1.0

# %%
def missingvaluecol(dff,value):
    

    for col in df.columns: 
        per_null=(df[col].isnull().sum())/(len(df))
        if per_null >= 0.20: 
            df1=df.drop([col])
        
        return df1

# %%
df
# Out:
#       A     B   C       D     E   F     H    I
# 0  Jack   NaN  34  Sydney   NaN   5   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12  11.0  1.0

# %% [markdown]
# def missingvaluecol(dff, value):
#
#     p_null = df.isnull().sum() / len(df)
#
#     missing_features = p_null[p_null > 0.95].index
#
#     df.drop(missing_features, axis=1, inplace=True)
#
#     return df

# %% [markdown]
# missingvaluecol(df,50)

# %% [markdown]
# p_null = df.isnull().sum() / len(df)
# missing_features = p_null[p_null > 0.70].index
# df.drop(missing_features, axis=1, inplace=True)

# %%
df
# Out:
#       A     B   C       D     E   F   G     H    I
# 0  Jack   NaN  34  Sydney   NaN   5 NaN   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7 NaN   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11 NaN   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12 NaN  11.0  1.0

# %%
df.isnull().sum()/len(df)
# Out:
# A    0.25
# B    0.75
# C    0.00
# D    0.25
# E    0.75
# F    0.00
# G    1.00
# H    0.50
# I    0.75
# dtype: float64

# %%
df

# %%
def f(i):
    return i

    for i in range(3):    
        f_with_i = functools.partial(f, i)  # important: use a different variable than "f"
        functions.append(f_with_i)

# %%
f(2)
# Out:
# 2

# %%
f(5)
# Out:
# 5

# %%
def fill_null_values(value,*dtype):
    
    value.dtype = dtype
    return result

  # to handle string data type
    if dtype  == 'object':
        result = '-999999'

  # to handle numeric data type
    elif ('int64' in dtype ) or ('float64' in dtype ):
        result = 0

  # add more cases to handle more data type

    return value.fillna(result)

# %%
import pandas as pd
import numpy as np
# List of Tuples
empoyees = [('Jack', np.NaN, 34, 'Sydney', np.NaN,  5,  np.NaN, np.NaN, np.NaN),
            ('Riti', 23    , 31, np.NaN , np.NaN,  7,  np.NaN, np.NaN, np.NaN),
            (np.NaN, np.NaN, 16, 'London', 32,      11, np.NaN, 3, np.NaN),
            ('Mark', np.NaN, 41, 'Delhi' , np.NaN,  12, np.NaN, 11, 1)]


# Create a DataFrame object
df = pd.DataFrame(  empoyees,
                    columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'])



df
# Out:
#       A     B   C       D     E   F   G     H    I
# 0  Jack   NaN  34  Sydney   NaN   5 NaN   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7 NaN   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11 NaN   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12 NaN  11.0  1.0

# %%
def missingvaluecol(dff,value):
    

    for col in df.columns: 
        per_null=(df[col].isnull().sum())/(len(df))
        if per_null >= 0.20: 
            df1=df.drop([col])
        
        return df1

# %%
df.isnull().sum()/(len(df))
# Out:
# A    0.25
# B    0.75
# C    0.00
# D    0.25
# E    0.75
# F    0.00
# G    1.00
# H    0.50
# I    0.75
# dtype: float64

# %%
def missingvaluecol(dff, value):
    
    p_null = df.isnull().sum() / len(df)
    
    missing_features = p_null[p_null > 0.9].index
    
    df.drop(missing_features, axis=1, inplace=True)

# %%
missingvaluecol(df, 0.95)

# %%
df
# Out:
#       A     B   C       D     E   F     H    I
# 0  Jack   NaN  34  Sydney   NaN   5   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12  11.0  1.0

# %%
df
# Out:
#       A     B   C       D     E   F   G     H    I
# 0  Jack   NaN  34  Sydney   NaN   5 NaN   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7 NaN   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11 NaN   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12 NaN  11.0  1.0

# %%
def null_value_treatment(df,value):

    for col in df.columns: 
        if sum(df[col].isnull())/float(len(df.index)) > 0.95: 
            del df[col]
            
        if df.transform(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0)):
            return df

# %%
null_value_treatment(df,0.95)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-da9b1a8b333f> in <module>
# ----> 1 null_value_treatment(df,0.95)
#
# <ipython-input-34-a9d6e63516c2> in null_value_treatment(df, value)
#       5             del df[col]
#       6
# ----> 7         if df.transform(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0)):
#       8             return df
#       9
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df
# Out:
#       A     B   C       D     E   F   G     H    I
# 0  Jack   NaN  34  Sydney   NaN   5 NaN   NaN  NaN
# 1  Riti  23.0  31     NaN   NaN   7 NaN   NaN  NaN
# 2   NaN   NaN  16  London  32.0  11 NaN   3.0  NaN
# 3  Mark   NaN  41   Delhi   NaN  12 NaN  11.0  1.0

# %%
for col in df.columns: 
        if (df[col].isnull().sum())/(len(df)) > 0.95: 
            del df[col]
df.transform(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0))
# Out:
#         A     B   C       D     E   F     H    I
# 0    Jack   0.0  34  Sydney   0.0   5   0.0  0.0
# 1    Riti  23.0  31  -99999   0.0   7   0.0  0.0
# 2  -99999   0.0  16  London  32.0  11   3.0  0.0
# 3    Mark   0.0  41   Delhi   0.0  12  11.0  1.0

# %%
df(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-e43d584d0a62> in <module>
# ----> 1 df(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0))
#
# TypeError: 'DataFrame' object is not callable
