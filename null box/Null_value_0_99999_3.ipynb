# %%
import pandas as pd
import numpy as np

# %%
empoyees = [('Jack', np.NaN, 34, 'Sydney', np.NaN,  5,  np.NaN, np.NaN, np.NaN),
            ('Riti', 23    , 31, np.NaN , np.NaN,  7,  np.NaN, np.NaN, np.NaN),
            (np.NaN, np.NaN, 16, 'London', 32,      11, np.NaN, 3, np.NaN),
            ('Mark', np.NaN, 41, 'Delhi' , np.NaN,  12, np.NaN, 11, 1)]



# Create a DataFrame object
df = pd.DataFrame(  empoyees,
                    columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'])

# %%
# importing libraries
import pandas as pd
import numpy as np
  
nums = {'Student Name': [ np.nan, 'Shivansh', 'Ishdeep',  
                         'Siddharth', np.nan, 'Prakhar',
                         'Yash', 'Srikar', 'Kaustubh', 
                         'Aditya',  'Manav', np.nan],
        'Roll No.': [ 18229, 18232, np.nan, 18247, 18136, 
                     np.nan, 18283, 18310, 18102, 18012,
                     18121, 18168],
       "Location": [np.NaN, np.NaN, "goa", 'up', "odisha", "mp", np.NaN,"hdy", np.NaN,np.NaN, np.NaN, "goa"],
        "Class": [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan],
        "Sex":["male","female",np.nan,np.nan,"male","female",np.nan,np.nan,"male","female",np.nan,np.nan],
        'Subject ID': [204, np.nan, 201, 105, np.nan, 204,
                       101, 101, np.nan, 165, 715, np.nan],
       'Grade Point': [9, np.nan, 7, np.nan, 8, 7, 9, 10,
                       np.nan, 9, 6, 8],
        "Age": [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]
       }
  # Create the dataframe
df = pd.DataFrame(nums)
  
df
# Out:
#    Student Name  Roll No. Location  Class     Sex  Subject ID  Grade Point  \
# 0           NaN   18229.0      NaN    NaN    male       204.0          9.0
# 1      Shivansh   18232.0      NaN    NaN  female         NaN          NaN
# 2       Ishdeep       NaN      goa    NaN     NaN       201.0          7.0
# 3     Siddharth   18247.0       up    NaN     NaN       105.0          NaN
# 4           NaN   18136.0   odisha    NaN    male         NaN          8.0
# 5       Prakhar       NaN       mp    NaN  female       204.0          7.0
# 6          Yash   18283.0      NaN    NaN     NaN       101.0          9.0
# 7        Srikar   18310.0      hdy    NaN     NaN       101.0         10.0
# 8      Kaustubh   18102.0      NaN    NaN    male         NaN          NaN
# 9        Aditya   18012.0      NaN    NaN  female       165.0          9.0
# 10        Manav   18121.0      NaN    NaN     NaN       715.0          6.0
# ...

# %%
df.isnull().sum()
# Out:
# Student Name     3
# Roll No.         2
# Location         6
# Class           12
# Sex              6
# Subject ID       4
# Grade Point      3
# Age             12
# dtype: int64

# %%
for col in df.columns: 
        if sum(df[col].isnull())/float(len(df.index)) > 0.95: 
            del df[col]
df
# Out:
#    Student Name  Roll No. Location     Sex  Subject ID  Grade Point
# 0           NaN   18229.0      NaN    male       204.0          9.0
# 1      Shivansh   18232.0      NaN  female         NaN          NaN
# 2       Ishdeep       NaN      goa     NaN       201.0          7.0
# 3     Siddharth   18247.0       up     NaN       105.0          NaN
# 4           NaN   18136.0   odisha    male         NaN          8.0
# 5       Prakhar       NaN       mp  female       204.0          7.0
# 6          Yash   18283.0      NaN     NaN       101.0          9.0
# 7        Srikar   18310.0      hdy     NaN       101.0         10.0
# 8      Kaustubh   18102.0      NaN    male         NaN          NaN
# 9        Aditya   18012.0      NaN  female       165.0          9.0
# 10        Manav   18121.0      NaN     NaN       715.0          6.0
# 11          NaN   18168.0      goa     NaN         NaN          8.0

# %%
if df.transform(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0))
# Out:
#   File "<ipython-input-72-ef41df539266>", line 1
#     if df.transform(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0))
#                                                                                          ^
# SyntaxError: invalid syntax

# %%
null_value_treatment(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-2cbae94deee2> in <module>
# ----> 1 null_value_treatment(df)
#
# <ipython-input-74-8599ea0d6663> in null_value_treatment(df)
#       5             del df[col]
#       6
# ----> 7         if df.transform(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0)):
#       8             return df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
def null_value_treatment(df):

    for col in df.columns: 
        if sum(df[col].isnull())/float(len(df.index)) > 0.95: 
            del df[col]
            
        if df.transform(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0)):
            return df

# %%
df.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
len(df.index)
# Out:
# 12

# %%
df.isnull()/len(df.index)
# Out:
#     Student Name  Roll No.  Location     Class       Sex  Subject ID  \
# 0       0.083333  0.000000  0.083333  0.083333  0.000000    0.000000
# 1       0.000000  0.000000  0.083333  0.083333  0.000000    0.083333
# 2       0.000000  0.083333  0.000000  0.083333  0.083333    0.000000
# 3       0.000000  0.000000  0.000000  0.083333  0.083333    0.000000
# 4       0.083333  0.000000  0.000000  0.083333  0.000000    0.083333
# 5       0.000000  0.083333  0.000000  0.083333  0.000000    0.000000
# 6       0.000000  0.000000  0.083333  0.083333  0.083333    0.000000
# 7       0.000000  0.000000  0.000000  0.083333  0.083333    0.000000
# 8       0.000000  0.000000  0.083333  0.083333  0.000000    0.083333
# 9       0.000000  0.000000  0.083333  0.083333  0.000000    0.000000
# 10      0.000000  0.000000  0.083333  0.083333  0.083333    0.000000
# 11      0.083333  0.000000  0.000000  0.083333  0.083333    0.083333
#
#     Grade Point       Age
# 0      0.000000  0.083333
# ...

# %%
for col in df.columns: 
    if sum(df[col].isnull())/len(df.index)>0.95: 
        del df[col]
        
df
# Out:
#    Student Name  Roll No. Location     Sex  Subject ID  Grade Point
# 0           NaN   18229.0      NaN    male       204.0          9.0
# 1      Shivansh   18232.0      NaN  female         NaN          NaN
# 2       Ishdeep       NaN      goa     NaN       201.0          7.0
# 3     Siddharth   18247.0       up     NaN       105.0          NaN
# 4           NaN   18136.0   odisha    male         NaN          8.0
# 5       Prakhar       NaN       mp  female       204.0          7.0
# 6          Yash   18283.0      NaN     NaN       101.0          9.0
# 7        Srikar   18310.0      hdy     NaN       101.0         10.0
# 8      Kaustubh   18102.0      NaN    male         NaN          NaN
# 9        Aditya   18012.0      NaN  female       165.0          9.0
# 10        Manav   18121.0      NaN     NaN       715.0          6.0
# 11          NaN   18168.0      goa     NaN         NaN          8.0

# %%
def fill_null_values(value,*dtype):
    
    value.dtype = dtype
    return result

  # to handle string data type
    if dtype  == 'object':
        result = '-999999'

  # to handle numeric data type
    elif ('int64' in dtype ) or ('float64' in dtype ):
        result = 0

  # add more cases to handle more data type

    return value.fillna(result)

# %%
fill_null_values(-99999,"object")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-52a5d6414e68> in <module>
# ----> 1 fill_null_values(-99999,"object")
#
# <ipython-input-40-fdc668e45531> in fill_null_values(value, *dtype)
#       1 def fill_null_values(value,*dtype):
#       2
# ----> 3     value.dtype = dtype
#       4     return result
#       5
#
# AttributeError: 'int' object has no attribute 'dtype'

# %%
# importing libraries
import pandas as pd
import numpy as np
  
nums = {'Student Name': [ np.nan, 'Shivansh', 'Ishdeep',  
                         'Siddharth', np.nan, 'Prakhar',
                         'Yash', 'Srikar', 'Kaustubh', 
                         'Aditya',  'Manav', np.nan],
        'Roll No.': [ 18229, 18232, np.nan, 18247, 18136, 
                     np.nan, 18283, 18310, 18102, 18012,
                     18121, 18168],
       "Location": [np.NaN, np.NaN, "goa", 'up', "odisha", "mp", np.NaN,"hdy", np.NaN,np.NaN, np.NaN, "goa"],
        "Class": [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan],
        "Sex":["male","female",np.nan,np.nan,"male","female",np.nan,np.nan,"male","female",np.nan,np.nan],
        'Subject ID': [204, np.nan, 201, 105, np.nan, 204,
                       101, 101, np.nan, 165, 715, np.nan],
       'Grade Point': [9, np.nan, 7, np.nan, 8, 7, 9, 10,
                       np.nan, 9, 6, 8],
        "Age": [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]
       }
  # Create the dataframe
df = pd.DataFrame(nums)
  
df
# Out:
#    Student Name  Roll No. Location  Class     Sex  Subject ID  Grade Point  \
# 0           NaN   18229.0      NaN    NaN    male       204.0          9.0
# 1      Shivansh   18232.0      NaN    NaN  female         NaN          NaN
# 2       Ishdeep       NaN      goa    NaN     NaN       201.0          7.0
# 3     Siddharth   18247.0       up    NaN     NaN       105.0          NaN
# 4           NaN   18136.0   odisha    NaN    male         NaN          8.0
# 5       Prakhar       NaN       mp    NaN  female       204.0          7.0
# 6          Yash   18283.0      NaN    NaN     NaN       101.0          9.0
# 7        Srikar   18310.0      hdy    NaN     NaN       101.0         10.0
# 8      Kaustubh   18102.0      NaN    NaN    male         NaN          NaN
# 9        Aditya   18012.0      NaN    NaN  female       165.0          9.0
# 10        Manav   18121.0      NaN    NaN     NaN       715.0          6.0
# ...

# %%
for col in df.columns: 
        if (df[col].isnull().sum())/(len(df)) > 0.95: 
            del df[col]
df.transform(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0))
# Out:
#    Student Name  Roll No. Location     Sex  Subject ID  Grade Point
# 0        -99999   18229.0   -99999    male       204.0          9.0
# 1      Shivansh   18232.0   -99999  female         0.0          0.0
# 2       Ishdeep       0.0      goa  -99999       201.0          7.0
# 3     Siddharth   18247.0       up  -99999       105.0          0.0
# 4        -99999   18136.0   odisha    male         0.0          8.0
# 5       Prakhar       0.0       mp  female       204.0          7.0
# 6          Yash   18283.0   -99999  -99999       101.0          9.0
# 7        Srikar   18310.0      hdy  -99999       101.0         10.0
# 8      Kaustubh   18102.0   -99999    male         0.0          0.0
# 9        Aditya   18012.0   -99999  female       165.0          9.0
# 10        Manav   18121.0   -99999  -99999       715.0          6.0
# 11       -99999   18168.0      goa  -99999         0.0          8.0

# %%
def null_value_treatment(df,value):
    for col in df.columns: 
        if (df[col].isnull().sum())/(len(df)) > 0.95: 
            del df[col]
        return df.transform(lambda x: x.fillna('-99999') if x.dtype == 'object' else x.fillna(0))

# %%
null_value_treatment(df,0.80)
# Out:
#    Student Name  Roll No. Location     Sex  Subject ID  Grade Point
# 0        -99999   18229.0   -99999    male       204.0          9.0
# 1      Shivansh   18232.0   -99999  female         0.0          0.0
# 2       Ishdeep       0.0      goa  -99999       201.0          7.0
# 3     Siddharth   18247.0       up  -99999       105.0          0.0
# 4        -99999   18136.0   odisha    male         0.0          8.0
# 5       Prakhar       0.0       mp  female       204.0          7.0
# 6          Yash   18283.0   -99999  -99999       101.0          9.0
# 7        Srikar   18310.0      hdy  -99999       101.0         10.0
# 8      Kaustubh   18102.0   -99999    male         0.0          0.0
# 9        Aditya   18012.0   -99999  female       165.0          9.0
# 10        Manav   18121.0   -99999  -99999       715.0          6.0
# 11       -99999   18168.0      goa  -99999         0.0          8.0

# %%
df
# Out:
#    Student Name  Roll No. Location     Sex  Subject ID  Grade Point
# 0           NaN   18229.0      NaN    male       204.0          9.0
# 1      Shivansh   18232.0      NaN  female         NaN          NaN
# 2       Ishdeep       NaN      goa     NaN       201.0          7.0
# 3     Siddharth   18247.0       up     NaN       105.0          NaN
# 4           NaN   18136.0   odisha    male         NaN          8.0
# 5       Prakhar       NaN       mp  female       204.0          7.0
# 6          Yash   18283.0      NaN     NaN       101.0          9.0
# 7        Srikar   18310.0      hdy     NaN       101.0         10.0
# 8      Kaustubh   18102.0      NaN    male         NaN          NaN
# 9        Aditya   18012.0      NaN  female       165.0          9.0
# 10        Manav   18121.0      NaN     NaN       715.0          6.0
# 11          NaN   18168.0      goa     NaN         NaN          8.0
